# %%
import tensorflow as tf
import keras
import time
# Out:
# 2025-07-04 03:10:01.837379: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-04 03:10:01.892887: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9373] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-04 03:10:01.892946: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-04 03:10:01.895113: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1534] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-04 03:10:01.905123: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def get_compiled_model():
    model = tf.keras.Sequential([
        tf.keras.applications.ConvNeXtLarge(include_top=False, input_shape=(32, 32, 3)),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10)
    ])
    model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        metrics=['accuracy'])
    
    return model


def get_dataset():
    batch_size_per_replica = 512
    batch_size = batch_size_per_replica * strategy.num_replicas_in_sync
    num_val_samples = 10000

    # Return the MNIST dataset in the form of a `tf.data.Dataset`.
    (x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

    # Preprocess the data (these are Numpy arrays)
    x_train = x_train.astype("float32") / 255
    x_test = x_test.astype("float32") / 255
    y_train = y_train.astype("float32")
    y_test = y_test.astype("float32")

    # Reserve num_val_samples samples for validation
    x_val = x_train[-num_val_samples:]
    y_val = y_train[-num_val_samples:]
    x_train = x_train[:-num_val_samples]
    y_train = y_train[:-num_val_samples]
    return (
        tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(batch_size),
        tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(batch_size),
        tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(batch_size),
    )

class timecallback(tf.keras.callbacks.Callback):
    def __init__(self):
        self.times = []
        # use this value as reference to calculate cummulative time taken
        self.start_time = time.perf_counter()
        self.end_time = time.perf_counter()
    def on_epoch_begin(self,epoch,logs = {}):
        self.start_time = time.perf_counter()
    def on_epoch_end(self,epoch,logs = {}):
        self.end_time = time.perf_counter()
        print('\nepoch time: ',self.end_time - self.start_time)

# %% [markdown]
# # Using 3 GPUs

# %%
# Create a MirroredStrategy.
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1", "/gpu:2"]) # use 3 GPUs
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2')
# 2025-07-04 03:10:05.002388: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1926] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43358 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:83:00.0, compute capability: 8.9
# 2025-07-04 03:10:05.003550: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1926] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 43358 MB memory:  -> device: 1, name: NVIDIA L40S, pci bus id: 0000:84:00.0, compute capability: 8.9
# 2025-07-04 03:10:05.004569: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1926] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 43358 MB memory:  -> device: 2, name: NVIDIA L40S, pci bus id: 0000:e3:00.0, compute capability: 8.9
# 2025-07-04 03:10:05.005492: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1926] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 43358 MB memory:  -> device: 3, name: NVIDIA L40S, pci bus id: 0000:e4:00.0, compute capability: 8.9
# Number of devices: 3

# %%
# %%time      
# Open a strategy scope.
with strategy.scope():
    # Everything that creates variables should be under the strategy scope.
    # In general this is only model construction & `compile()`.
    model = get_compiled_model()
        
# Train the model on all available devices.
train_dataset, val_dataset, test_dataset = get_dataset()
timetaken = timecallback()
model.fit(train_dataset, epochs=50, validation_data=val_dataset, callbacks = [timetaken])

# Test the model on all available devices.
model.evaluate(test_dataset)
# Out:
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 346 all_reduces, num_devices = 3, group_size = 3, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Collective all_reduce tensors: 346 all_reduces, num_devices = 3, group_size = 3, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2025-07-04 03:12:05.251031: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:467] Loaded cuDNN version 90100
# 2025-07-04 03:12:05.363696: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:467] Loaded cuDNN version 90100
# 2025-07-04 03:12:05.380665: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:467] Loaded cuDNN version 90100
# 2025-07-04 03:12:05.969766: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fd21f361730 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-07-04 03:12:05.969813: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2025-07-04 03:12:05.969823: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA L40S, Compute Capability 8.9
# 2025-07-04 03:12:05.969831: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (2): NVIDIA L40S, Compute Capability 8.9
# 2025-07-04 03:12:05.969841: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (3): NVIDIA L40S, Compute Capability 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751598726.470418  240133 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-07-04 03:12:20.420230: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 27/27 [==============================] - ETA: 0s - loss: 2.4831 - accuracy: 0.0980INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
#
# epoch time:  183.2238174006343
# 27/27 [==============================] - 183s 1s/step - loss: 2.4831 - accuracy: 0.0980 - val_loss: 2.3111 - val_accuracy: 0.0980
# Epoch 2/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3058 - accuracy: 0.1002
# epoch time:  9.34353987313807
# 27/27 [==============================] - 9s 344ms/step - loss: 2.3058 - accuracy: 0.1002 - val_loss: 2.3059 - val_accuracy: 0.0958
# Epoch 3/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3035 - accuracy: 0.1000
# epoch time:  9.167152354493737
# 27/27 [==============================] - 9s 341ms/step - loss: 2.3035 - accuracy: 0.1000 - val_loss: 2.3027 - val_accuracy: 0.0958
# Epoch 4/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1012
# epoch time:  8.86977688036859
# 27/27 [==============================] - 9s 329ms/step - loss: 2.3026 - accuracy: 0.1012 - val_loss: 2.3027 - val_accuracy: 0.0958
# Epoch 5/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1012
# epoch time:  8.80012402497232
# 27/27 [==============================] - 9s 326ms/step - loss: 2.3026 - accuracy: 0.1012 - val_loss: 2.3027 - val_accuracy: 0.0958
# Epoch 6/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1012
# epoch time:  8.654516816139221
# 27/27 [==============================] - 9s 322ms/step - loss: 2.3026 - accuracy: 0.1012 - val_loss: 2.3027 - val_accuracy: 0.0958
# Epoch 7/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1012
# epoch time:  8.75357598438859
# 27/27 [==============================] - 9s 324ms/step - loss: 2.3026 - accuracy: 0.1012 - val_loss: 2.3028 - val_accuracy: 0.0958
# Epoch 8/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1012
# epoch time:  8.64027924835682
# 27/27 [==============================] - 9s 321ms/step - loss: 2.3026 - accuracy: 0.1012 - val_loss: 2.3028 - val_accuracy: 0.0958
# Epoch 9/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1012
# epoch time:  8.694978900253773
# 27/27 [==============================] - 9s 321ms/step - loss: 2.3026 - accuracy: 0.1012 - val_loss: 2.3028 - val_accuracy: 0.0958
# Epoch 10/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1012
# epoch time:  8.762102488428354
# 27/27 [==============================] - 9s 326ms/step - loss: 2.3026 - accuracy: 0.1012 - val_loss: 2.3028 - val_accuracy: 0.0958
# Epoch 11/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.0998
# epoch time:  8.515903929248452
# 27/27 [==============================] - 9s 316ms/step - loss: 2.3026 - accuracy: 0.0998 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 12/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  8.898496896028519
# 27/27 [==============================] - 9s 330ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 13/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  8.522741423919797
# 27/27 [==============================] - 9s 316ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 14/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  8.449284287169576
# 27/27 [==============================] - 8s 313ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 15/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  8.426803903654218
# 27/27 [==============================] - 8s 313ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 16/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  8.605744924396276
# 27/27 [==============================] - 9s 320ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 17/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  8.735477812588215
# 27/27 [==============================] - 9s 325ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 18/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  8.878599811345339
# 27/27 [==============================] - 9s 330ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 19/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.94493342936039
# 27/27 [==============================] - 9s 332ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 20/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  9.027065392583609
# 27/27 [==============================] - 9s 336ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 21/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.94885116815567
# 27/27 [==============================] - 9s 332ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 22/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.905889626592398
# 27/27 [==============================] - 9s 332ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 23/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  9.807186271995306
# 27/27 [==============================] - 10s 366ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 24/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.71416674181819
# 27/27 [==============================] - 9s 323ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 25/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.847491014748812
# 27/27 [==============================] - 9s 329ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 26/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.867367280647159
# 27/27 [==============================] - 9s 330ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 27/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.92805233411491
# 27/27 [==============================] - 9s 332ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 28/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.820604911074042
# 27/27 [==============================] - 9s 328ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 29/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.844797126948833
# 27/27 [==============================] - 9s 329ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 30/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.318396968767047
# 27/27 [==============================] - 8s 309ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 31/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.380463249981403
# 27/27 [==============================] - 8s 311ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 32/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.351629352197051
# 27/27 [==============================] - 8s 311ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 33/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.397632785141468
# 27/27 [==============================] - 8s 312ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 34/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.401454141363502
# 27/27 [==============================] - 8s 311ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 35/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.50616112910211
# 27/27 [==============================] - 9s 316ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 36/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.543303184211254
# 27/27 [==============================] - 9s 317ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 37/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.61375292018056
# 27/27 [==============================] - 9s 320ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 38/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.602542964741588
# 27/27 [==============================] - 9s 320ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 39/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.635638924315572
# 27/27 [==============================] - 9s 321ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 40/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.481272615492344
# 27/27 [==============================] - 8s 315ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 41/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.555316679179668
# 27/27 [==============================] - 9s 318ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 42/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.802223391830921
# 27/27 [==============================] - 9s 328ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 43/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.77183604799211
# 27/27 [==============================] - 9s 326ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 44/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.702993229031563
# 27/27 [==============================] - 9s 323ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 45/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.742599060758948
# 27/27 [==============================] - 9s 325ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 46/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.595743231475353
# 27/27 [==============================] - 9s 319ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 47/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.719944881275296
# 27/27 [==============================] - 9s 325ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 48/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.653187062591314
# 27/27 [==============================] - 9s 322ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 49/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.747058590874076
# 27/27 [==============================] - 9s 325ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 50/50
# 27/27 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1004
# epoch time:  8.784387854859233
# 27/27 [==============================] - 9s 326ms/step - loss: 2.3027 - accuracy: 0.1004 - val_loss: 2.3030 - val_accuracy: 0.0980
# 7/7 [==============================] - 1s 65ms/step - loss: 2.3027 - accuracy: 0.1002
# CPU times: user 20min 43s, sys: 4min 48s, total: 25min 31s
# Wall time: 10min 48s
# [2.302734851837158, 0.10017670691013336]
