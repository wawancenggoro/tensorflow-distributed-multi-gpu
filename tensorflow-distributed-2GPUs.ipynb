# %%
import tensorflow as tf
import keras
import time
# Out:
# 2025-07-04 04:09:23.949096: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-04 04:09:24.004712: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9373] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-04 04:09:24.004773: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-04 04:09:24.006927: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1534] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-04 04:09:24.016971: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def get_compiled_model():
    model = tf.keras.Sequential([
        tf.keras.applications.ConvNeXtLarge(include_top=False, input_shape=(32, 32, 3)),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(10)
    ])
    model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        metrics=['accuracy'])
    
    return model


def get_dataset():
    batch_size_per_replica = 512
    batch_size = batch_size_per_replica * strategy.num_replicas_in_sync
    num_val_samples = 10000

    # Return the MNIST dataset in the form of a `tf.data.Dataset`.
    (x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

    # Preprocess the data (these are Numpy arrays)
    x_train = x_train.astype("float32") / 255
    x_test = x_test.astype("float32") / 255
    y_train = y_train.astype("float32")
    y_test = y_test.astype("float32")

    # Reserve num_val_samples samples for validation
    x_val = x_train[-num_val_samples:]
    y_val = y_train[-num_val_samples:]
    x_train = x_train[:-num_val_samples]
    y_train = y_train[:-num_val_samples]
    return (
        tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(batch_size),
        tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(batch_size),
        tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(batch_size),
    )

class timecallback(tf.keras.callbacks.Callback):
    def __init__(self):
        self.times = []
        # use this value as reference to calculate cummulative time taken
        self.start_time = time.perf_counter()
        self.end_time = time.perf_counter()
    def on_epoch_begin(self,epoch,logs = {}):
        self.start_time = time.perf_counter()
    def on_epoch_end(self,epoch,logs = {}):
        self.end_time = time.perf_counter()
        print('\nepoch time: ',self.end_time - self.start_time)

# %% [markdown]
# # Using 4 GPUs

# %%
# Create a MirroredStrategy.
strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"]) # use 2 GPUs
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# 2025-07-04 04:09:27.377405: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1926] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43358 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:83:00.0, compute capability: 8.9
# 2025-07-04 04:09:27.378786: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1926] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 43358 MB memory:  -> device: 1, name: NVIDIA L40S, pci bus id: 0000:84:00.0, compute capability: 8.9
# 2025-07-04 04:09:27.379681: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1926] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 43358 MB memory:  -> device: 2, name: NVIDIA L40S, pci bus id: 0000:e3:00.0, compute capability: 8.9
# 2025-07-04 04:09:27.380629: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1926] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 43358 MB memory:  -> device: 3, name: NVIDIA L40S, pci bus id: 0000:e4:00.0, compute capability: 8.9
# Number of devices: 2

# %%
# %%time      
# Open a strategy scope.
with strategy.scope():
    # Everything that creates variables should be under the strategy scope.
    # In general this is only model construction & `compile()`.
    model = get_compiled_model()
        
# Train the model on all available devices.
train_dataset, val_dataset, test_dataset = get_dataset()
timetaken = timecallback()
model.fit(train_dataset, epochs=50, validation_data=val_dataset, callbacks = [timetaken])

# Test the model on all available devices.
model.evaluate(test_dataset)
# Out:
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 346 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Collective all_reduce tensors: 346 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2025-07-04 04:10:49.513199: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:467] Loaded cuDNN version 90100
# 2025-07-04 04:10:49.600192: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:467] Loaded cuDNN version 90100
# 2025-07-04 04:10:50.198498: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fdd1b933fb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-07-04 04:10:50.198542: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2025-07-04 04:10:50.198551: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA L40S, Compute Capability 8.9
# 2025-07-04 04:10:50.198561: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (2): NVIDIA L40S, Compute Capability 8.9
# 2025-07-04 04:10:50.198574: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (3): NVIDIA L40S, Compute Capability 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751602250.601080  479456 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-07-04 04:11:04.245365: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 40/40 [==============================] - ETA: 0s - loss: 2.4034 - accuracy: 0.1000INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
#
# epoch time:  145.0854188092053
# 40/40 [==============================] - 145s 809ms/step - loss: 2.4034 - accuracy: 0.1000 - val_loss: 2.3026 - val_accuracy: 0.1010
# Epoch 2/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.0996
# epoch time:  10.262137373909354
# 40/40 [==============================] - 10s 256ms/step - loss: 2.3026 - accuracy: 0.0996 - val_loss: 2.3026 - val_accuracy: 0.1010
# Epoch 3/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.0996
# epoch time:  10.217515477910638
# 40/40 [==============================] - 10s 255ms/step - loss: 2.3026 - accuracy: 0.0996 - val_loss: 2.3026 - val_accuracy: 0.1010
# Epoch 4/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.0988
# epoch time:  9.991629727184772
# 40/40 [==============================] - 10s 250ms/step - loss: 2.3026 - accuracy: 0.0988 - val_loss: 2.3027 - val_accuracy: 0.0980
# Epoch 5/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.025411477312446
# 40/40 [==============================] - 10s 251ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3027 - val_accuracy: 0.0980
# Epoch 6/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  11.00814968533814
# 40/40 [==============================] - 11s 275ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3027 - val_accuracy: 0.0980
# Epoch 7/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.009832110255957
# 40/40 [==============================] - 10s 251ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3028 - val_accuracy: 0.0980
# Epoch 8/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  9.834872707724571
# 40/40 [==============================] - 10s 245ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3028 - val_accuracy: 0.0980
# Epoch 9/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  9.882127422839403
# 40/40 [==============================] - 10s 248ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3028 - val_accuracy: 0.0980
# Epoch 10/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  9.934083048254251
# 40/40 [==============================] - 10s 249ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3028 - val_accuracy: 0.0980
# Epoch 11/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.030404563993216
# 40/40 [==============================] - 10s 251ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3028 - val_accuracy: 0.0980
# Epoch 12/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.258525725454092
# 40/40 [==============================] - 10s 256ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3028 - val_accuracy: 0.0980
# Epoch 13/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.474161574617028
# 40/40 [==============================] - 10s 262ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3028 - val_accuracy: 0.0980
# Epoch 14/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.570933250710368
# 40/40 [==============================] - 11s 264ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 15/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.49838687479496
# 40/40 [==============================] - 10s 262ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 16/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.323054052889347
# 40/40 [==============================] - 10s 259ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 17/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.107459584251046
# 40/40 [==============================] - 10s 253ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 18/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.007352706044912
# 40/40 [==============================] - 10s 250ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 19/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  9.935953732579947
# 40/40 [==============================] - 10s 249ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 20/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.20839117653668
# 40/40 [==============================] - 10s 256ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 21/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  9.939732227474451
# 40/40 [==============================] - 10s 249ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 22/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.42913276143372
# 40/40 [==============================] - 10s 261ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 23/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.049561781808734
# 40/40 [==============================] - 10s 252ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 24/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.360346054658294
# 40/40 [==============================] - 10s 260ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 25/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.419255197048187
# 40/40 [==============================] - 10s 260ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 26/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.001840451732278
# 40/40 [==============================] - 10s 251ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 27/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  9.946806211024523
# 40/40 [==============================] - 10s 249ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 28/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  9.955901088193059
# 40/40 [==============================] - 10s 249ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 29/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  9.882097698748112
# 40/40 [==============================] - 10s 247ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 30/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  9.792539624497294
# 40/40 [==============================] - 10s 245ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 31/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  9.746609413996339
# 40/40 [==============================] - 10s 244ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 32/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  9.654140016064048
# 40/40 [==============================] - 10s 242ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 33/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  9.857842784374952
# 40/40 [==============================] - 10s 247ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 34/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  9.74367268383503
# 40/40 [==============================] - 10s 244ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 35/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  9.787574216723442
# 40/40 [==============================] - 10s 245ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 36/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.44480480067432
# 40/40 [==============================] - 10s 261ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 37/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.394739132374525
# 40/40 [==============================] - 10s 260ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 38/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.180086221545935
# 40/40 [==============================] - 10s 254ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 39/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.308614699169993
# 40/40 [==============================] - 10s 258ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 40/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.327353686094284
# 40/40 [==============================] - 10s 258ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 41/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.260552139952779
# 40/40 [==============================] - 10s 257ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 42/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.622400313615799
# 40/40 [==============================] - 11s 266ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 43/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.301955906674266
# 40/40 [==============================] - 10s 258ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 44/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.137516714632511
# 40/40 [==============================] - 10s 254ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 45/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.257768919691443
# 40/40 [==============================] - 10s 257ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 46/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.134628612548113
# 40/40 [==============================] - 10s 254ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 47/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.390349691733718
# 40/40 [==============================] - 10s 261ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 48/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  10.083972360938787
# 40/40 [==============================] - 10s 253ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 49/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  9.764898482710123
# 40/40 [==============================] - 10s 245ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# Epoch 50/50
# 40/40 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1004
# epoch time:  9.734613828361034
# 40/40 [==============================] - 10s 244ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3029 - val_accuracy: 0.0980
# 10/10 [==============================] - 1s 56ms/step - loss: 2.3027 - accuracy: 0.1001
# CPU times: user 17min 29s, sys: 4min 39s, total: 22min 8s
# Wall time: 11min 17s
# [2.302661657333374, 0.1000811755657196]
